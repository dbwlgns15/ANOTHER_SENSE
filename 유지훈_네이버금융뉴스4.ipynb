# %%
import pandas as pd
import numpy as np
import re

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./src/네이버금융종목뉴스기사본문_카카오_전체_전처리후.csv')
df
# Out:
#               날짜                                          제목    정보제공  \
# 0     2022-04-29             "미래 푸드테크, 삼성·SK·네이버·카카오도 진출할 것"   머니투데이
# 1     2022-04-29              ‘상생 행보’ 카카오…중기유통센터 손잡고 소상공인 지원  이코노미스트
# 2     2022-04-29                  소상공인 파트너와 성장하는 ‘톡스토어’..카카오  파이낸셜뉴스
# 3     2022-04-28              "카카오·네이버보다도 못하다고?"…삼성맨들 '부글부글'    한국경제
# 4     2022-04-28  2040년까지 탄소 순 배출량 '0' 만든다…카카오 '넷 제로' 원칙 ...  이코노미스트
# ...          ...                                         ...     ...
# 5571  2021-05-03                  카카오-카카오커머스, ‘톡스토어 판매자’ 키운다  파이낸셜뉴스
# 5572  2021-05-03             카카오·카카오커머스, '톡스토어' 판매자 양성 과정 진행    서울경제
# 5573  2021-05-01             KT와 카카오의 공유자전거 힘겨루기…T바이크에 타조 맞불    매일경제
# 5574  2021-04-30             네이버 오른다는데…공매도 타깃된 카카오 "나 떨고있니?"   머니투데이
# 5575  2021-04-30               카카오내비, ‘방문 정비’ 시작 “주행분석까지 한다”  파이낸셜뉴스
#
#                                                      링크  \
# 0     https://finance.naver.com/item/news_read.naver...
# ...

# %%
df2 = pd.read_csv('./src/네이버금융종목뉴스링크_카카오_관련뉴스.csv')
df2
# Out:
#               날짜                                제목    정보제공  \
# 0     2022-04-29        소상공인 파트너와 성장하는 ‘톡스토어’..카카오  파이낸셜뉴스
# 1     2022-04-28    카카오 공동체, 2040년까지 온실가스 배출 제로 선언    이데일리
# 2     2022-04-28     카카오 기후위기 대응 원칙 수립…"ESG 경영 강화"    서울경제
# 3     2022-04-27        카카오웹툰, 인도네시아 진출…"아세안으로 확장"    한국경제
# 4     2022-04-27       카카오엔터, ‘카카오웹툰 인도네시아’ 27일 론칭  파이낸셜뉴스
# ...          ...                               ...     ...
# 1891  2021-05-04   카카오, 전 직원에 3년간 최대 600주씩 스톡옵션 부여   머니투데이
# 1892  2021-05-04     통 큰 결단 내린 카카오, 전 직원에 스톡옵션 뿌린다    한국경제
# 1893  2021-05-04  카카오, 539억 규모 본사 직원 대상 스톡옵션 부여 결정   아시아경제
# 1894  2021-05-04           네이버 이어 카카오도 전직원 스톡옵션 쏜다  파이낸셜뉴스
# 1895  2021-05-04  카카오, 539억 규모 본사 직원 대상 스톡옵션 부여 결정   아시아경제
#
#                                                      링크
# 0     https://finance.naver.com/item/news_read.naver...
# 1     https://finance.naver.com/item/news_read.naver...
# 2     https://finance.naver.com/item/news_read.naver...
# ...

# %%
df3 = df.append(df2)
df3
# Out:
#               날짜                                          제목    정보제공  \
# 0     2022-04-29             "미래 푸드테크, 삼성·SK·네이버·카카오도 진출할 것"   머니투데이
# 1     2022-04-29              ‘상생 행보’ 카카오…중기유통센터 손잡고 소상공인 지원  이코노미스트
# 2     2022-04-29                  소상공인 파트너와 성장하는 ‘톡스토어’..카카오  파이낸셜뉴스
# 3     2022-04-28              "카카오·네이버보다도 못하다고?"…삼성맨들 '부글부글'    한국경제
# 4     2022-04-28  2040년까지 탄소 순 배출량 '0' 만든다…카카오 '넷 제로' 원칙 ...  이코노미스트
# ...          ...                                         ...     ...
# 1891  2021-05-04             카카오, 전 직원에 3년간 최대 600주씩 스톡옵션 부여   머니투데이
# 1892  2021-05-04               통 큰 결단 내린 카카오, 전 직원에 스톡옵션 뿌린다    한국경제
# 1893  2021-05-04            카카오, 539억 규모 본사 직원 대상 스톡옵션 부여 결정   아시아경제
# 1894  2021-05-04                     네이버 이어 카카오도 전직원 스톡옵션 쏜다  파이낸셜뉴스
# 1895  2021-05-04            카카오, 539억 규모 본사 직원 대상 스톡옵션 부여 결정   아시아경제
#
#                                                      링크  \
# 0     https://finance.naver.com/item/news_read.naver...
# ...

# %%
df3.drop_duplicates('링크',keep=False)
# Out:
#               날짜                                          제목    정보제공  \
# 0     2022-04-29             "미래 푸드테크, 삼성·SK·네이버·카카오도 진출할 것"   머니투데이
# 1     2022-04-29              ‘상생 행보’ 카카오…중기유통센터 손잡고 소상공인 지원  이코노미스트
# 3     2022-04-28              "카카오·네이버보다도 못하다고?"…삼성맨들 '부글부글'    한국경제
# 4     2022-04-28  2040년까지 탄소 순 배출량 '0' 만든다…카카오 '넷 제로' 원칙 ...  이코노미스트
# 5     2022-04-28              카카오 공동체, 'RE100' 가입 추진..ESG 강화  파이낸셜뉴스
# ...          ...                                         ...     ...
# 5571  2021-05-03                  카카오-카카오커머스, ‘톡스토어 판매자’ 키운다  파이낸셜뉴스
# 5572  2021-05-03             카카오·카카오커머스, '톡스토어' 판매자 양성 과정 진행    서울경제
# 5573  2021-05-01             KT와 카카오의 공유자전거 힘겨루기…T바이크에 타조 맞불    매일경제
# 5574  2021-04-30             네이버 오른다는데…공매도 타깃된 카카오 "나 떨고있니?"   머니투데이
# 5575  2021-04-30               카카오내비, ‘방문 정비’ 시작 “주행분석까지 한다”  파이낸셜뉴스
#
#                                                      링크  \
# 0     https://finance.naver.com/item/news_read.naver...
# ...

# %%
df3.to_csv("./src/네이버금융종목뉴스기사본문_카카오_전체_전처리후_관련기사제거.csv", index=False)
