# %%
import streamlit as st
import pandas as pd
from datetime import datetime,timedelta
import bs4
import requests
from pykrx import stock
import matplotlib.pyplot as plt
import numpy as np
from pymongo import MongoClient
import re
from PIL import Image
from datetime import date, timedelta

# %%
codes = ['035720','035420']
my_client = MongoClient('mongodb://18.181.49.139:27017')
mydb = my_client['final_project']
mydb['company_price'].delete_many({})

for code in codes:
    tp_price = stock.get_market_ohlcv_by_date(
                    fromdate=datetime.strftime(
                        (datetime.now()).date()-timedelta(days=1), '%Y-%m-%d'),
                    todate=datetime.strftime(
                        (datetime.now()).date()-timedelta(days=1), '%Y-%m-%d'),
                    ticker=code,
                    adjusted=False)
    
    
    tp = stock.get_market_ohlcv_by_date(
                    fromdate=datetime.strftime(
                        (datetime.now()).date(), '%Y-%m-%d'),
                    todate=datetime.strftime(
                        (datetime.now()).date(), '%Y-%m-%d'),
                    ticker=code,
                    adjusted=False)
    tp['전일비'] = tp.loc[datetime.strftime((datetime.now()).date(), '%Y-%m-%d'),'종가']-tp_price.loc[datetime.strftime((datetime.now()).date()-timedelta(days=1), '%Y-%m-%d'),'종가']

    tp['code'] = code
    tp.reset_index(inplace=True)
    
    mydb['company_price'].insert_many(tp.to_dict('records'))

# %%
codes = ['1001','2001']
my_client = MongoClient('mongodb://18.181.49.139:27017')
mydb = my_client['final_project']
mydb['side_price'].delete_many({})

for code in codes:
    tp_price = stock.get_index_fundamental(
                    datetime.strftime(
                        (datetime.now()).date()-timedelta(days=1), '%Y-%m-%d'),
                    datetime.strftime(
                        (datetime.now()).date()-timedelta(days=1), '%Y-%m-%d'),
                    ticker=code)
    
    
    tp = stock.get_index_fundamental(
                    datetime.strftime(
                        (datetime.now()).date(), '%Y-%m-%d'),
                    datetime.strftime(
                        (datetime.now()).date(), '%Y-%m-%d'),
                    ticker=code)
    tp['전일비'] = tp.loc[datetime.strftime((datetime.now()).date(), '%Y-%m-%d'),'종가']-tp_price.loc[datetime.strftime((datetime.now()).date()-timedelta(days=1), '%Y-%m-%d'),'종가']

    tp['code'] = code
    tp.reset_index(inplace=True)
    
    mydb['side_price'].insert_many(tp.to_dict('records'))

# %%
my_client = MongoClient('mongodb://18.181.49.139:27017')
mydb = my_client['final_project']

companys = ['kakao','naver']
day = 3
for company in companys:
    mydb[f'{company}_article'].delete_many({})

    date_list = []
    title_list = []
    info_list = []
    url_list = []

    if company == 'kakao':
        code = '035720' # kakao
    else:
        code = '035420' # naver
    page = 1

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.64 Safari/537.36 Edg/101.0.1210.32'}

    url = f'https://finance.naver.com/item/news_news.naver?code={code}&page={page}&sm=title_entity_id.basic&clusterId='
    res = requests.get(url, headers=headers)
    bs = bs4.BeautifulSoup(res.text, 'html.parser')

    while datetime.strftime(datetime.now().date() + timedelta(days=-day), '%Y-%m-%d') not in date_list:
        url = f'https://finance.naver.com/item/news_news.naver?code={code}&page={page}&sm=title_entity_id.basic&clusterId='
        res = requests.get(url, headers=headers)
        bs = bs4.BeautifulSoup(res.text, 'html.parser')

        date_list.extend([i.text.split()[0].replace('.', '-') for i in bs.find_all('td', {'class': 'date'})])
        title_list.extend([i.text.replace('\n', '').replace('[','').replace(']','') for i in bs.find_all('td', {'class': 'title'})])
        info_list.extend([i.text for i in bs.find_all('td', {'class': 'info'})])
        url_list.extend(
            ['https://finance.naver.com' + i.find('a')['href'] for i in bs.find_all('td', {'class': 'title'})])

        page += 1

    data = pd.DataFrame([date_list, title_list, info_list, url_list], index=['날짜', '제목', '정보제공', '링크']).transpose()
    data = data.drop_duplicates('제목')

    mydb[f'{company}_article'].insert_many(data.to_dict('records'))

# %%
my_client = MongoClient('mongodb://18.181.49.139:27017')
mydb = my_client['final_project']
pd.DataFrame(mydb['naver_article'].find({}))
# Out:
#                          _id          날짜  \
# 0   62a0ca01bca4c31991b00def  2022-06-08
# 1   62a0ca01bca4c31991b00df0  2022-06-08
# 2   62a0ca01bca4c31991b00df1  2022-06-08
# 3   62a0ca01bca4c31991b00df2  2022-06-08
# 4   62a0ca01bca4c31991b00df3  2022-06-08
# 5   62a0ca01bca4c31991b00df4  2022-06-08
# 6   62a0ca01bca4c31991b00df5  2022-06-08
# 7   62a0ca01bca4c31991b00df6  2022-06-08
# 8   62a0ca01bca4c31991b00df7  2022-06-08
# 9   62a0ca01bca4c31991b00df8  2022-06-08
# 10  62a0ca01bca4c31991b00df9  2022-06-08
# 11  62a0ca01bca4c31991b00dfa  2022-06-08
# 12  62a0ca01bca4c31991b00dfb  2022-06-07
# 13  62a0ca01bca4c31991b00dfc  2022-06-07
# 14  62a0ca01bca4c31991b00dfd  2022-06-07
# 15  62a0ca01bca4c31991b00dfe  2022-06-07
# 16  62a0ca01bca4c31991b00dff  2022-06-07
# 17  62a0ca01bca4c31991b00e00  2022-06-07
# 18  62a0ca01bca4c31991b00e01  2022-06-07
# 19  62a0ca01bca4c31991b00e02  2022-06-07
# 20  62a0ca01bca4c31991b00e03  2022-06-07
# 21  62a0ca01bca4c31991b00e04  2022-06-07
# 22  62a0ca01bca4c31991b00e05  2022-06-07
# 23  62a0ca01bca4c31991b00e06  2022-06-07
# 24  62a0ca01bca4c31991b00e07  2022-06-07
# 25  62a0ca01bca4c31991b00e08  2022-06-07
# 26  62a0ca01bca4c31991b00e09  2022-06-07
# 27  62a0ca01bca4c31991b00e0a  2022-06-07
# 28  62a0ca01bca4c31991b00e0b  2022-06-07
# 29  62a0ca01bca4c31991b00e0c  2022-06-07
# 30  62a0ca01bca4c31991b00e0d  2022-06-06
# 31  62a0ca01bca4c31991b00e0e  2022-06-06
# 32  62a0ca01bca4c31991b00e0f  2022-06-06
# 33  62a0ca01bca4c31991b00e10  2022-06-06
# 34  62a0ca01bca4c31991b00e11  2022-06-06
# 35  62a0ca01bca4c31991b00e12  2022-06-05
# 36  62a0ca01bca4c31991b00e13  2022-06-05
# 37  62a0ca01bca4c31991b00e14  2022-06-03
#
#                                            제목    정보제공  \
# 0                 네이버 '일할 맛나는' 신사옥 기술, 묶어서 판다  비즈니스워치
# 1   (영상)네이버, 미래형공간 대중화 본격화..."공간 개념 확 바꿀 것...    이데일리
# 2                   네이버 "5G·ARC 융합기술, 내년 상용화"    서울경제
# 3             “5층까지 짓다가…” 네이버 1784, 비싼 건물된 사연    이데일리
# 4             "로봇 아닌 '이것' 팔겠다" 네이버 밝힌 새 비즈니스는    매일경제
# 5              네이버, ARC·5G특화망으로 '스마트빌딩 시장' 진출    매일경제
# 6          네이버·카카오 등에 맞춤형 광고 집행…'크로스타겟' 확대 개편   머니투데이
# 7    AI World 2022 성낙호 네이버 책임리더 "AI도 인간처럼 ...  파이낸셜뉴스
# 8                          팀 네이버 ‘미래형 공간’ 대중화   헤럴드경제
# 9              네이버, ‘1784 로봇’ 본뜬 스마트빌딩 대중화 목표    이데일리
# 10  원하면 네이버 신사옥처럼 만들어드립니다…"로봇·클라우드 기술 2023...    서울경제
# 11       네이버 노조 "계열사 초임은 '본사 절반'…임금 똑같이 인상해야"   머니투데이
# 12            네이버플러스 멤버십 이용자 800만 돌파…상생도 꽃피운다  파이낸셜뉴스
# 13           '한달 4900원' 네이버플러스 2년만에 800만명이 썼다   머니투데이
# 14  "658만P 페이백받은 사용자도"…네이버 멤버십 1000만 돌파 '부...    서울경제
# 15               네이버플러스 멤버십, 화끈한 적립에 파트너사 웃었다    이데일리
# 16                   네이버, 세자릿수 신입 개발자 채용 진행한다  파이낸셜뉴스
# 17      네이버, 나만의 성장 트랙 직접 설계하는 ‘신입 개발자’ 채용 진행    이데일리
# 18                네이버, 세자릿수 규모 신입 및 인턴 개발자 채용   머니투데이
# 19                      애플워치로 결제하는 '네이버페이' 출시    한국경제
# 20                      네이버페이 현장결제…스마트워치로 손쉽게    매일경제
# 21                네이버파이낸셜, 스마트워치용 '페이 워치앱' 출시    서울경제
# 22             네이버파이낸셜, 스마트워치용 ‘네이버페이 워치앱’ 출시    조선비즈
# 23          네이버파이낸셜 “이제 휴대폰 없이 워치로 네이버페이 쓰세요”  이코노미스트
# 24                갤럭시·애플워치에서 네이버페이 결제된다…국내 최초   헤럴드경제
# 25    크래프톤 임원 7명 중 6명이 40대…카카오·네이버도 비중 70% 넘어    한국경제
# 26         (영상)삼성·네이버가 찍은 '이음5G' 확대일로...수혜주는?    이데일리
# 27                특징주외국인 엇갈린 선택…네이버 카카오 나란히 뚝    이데일리
# 28      교보악사자산운용, 네이버·카카오 투자하는 '플랫폼투게더' 펀드 출시    서울경제
# 29           코스피·코스닥 하락 출발, 네이버·카카오 2%대↓ 개장시황  이코노미스트
# 30  '인간지능과 AI의 만남'… KT·네이버·카카오엔터프라이즈 전략은 A...  파이낸셜뉴스
# 31    AI World 2022 KT-네이버-카카오엔터프라이즈, AI 핵...  파이낸셜뉴스
# 32                    매경이코노미, 네이버 구독자 100만 돌파    매일경제
# 33                     코스피 주간 개인 순매도 1위 '네이버'    이데일리
# 34            "성장주인가 가치주인가"…네이버·카카오 주가 부진한 이유    한국경제
# 35                    성장주 저문다더니…네이버 카카오 바닥찍었나   아시아경제
# 36                  존재감 커진 네이버 웨일…점유율 10%대 눈앞  매경이코노미
# 37           네이버 노조 "계열사 5곳 임금교섭 결렬…중노위 조정신청"   머니투데이
#
#                                                    링크
# 0   https://finance.naver.com/item/news_read.naver...
# 1   https://finance.naver.com/item/news_read.naver...
# 2   https://finance.naver.com/item/news_read.naver...
# 3   https://finance.naver.com/item/news_read.naver...
# 4   https://finance.naver.com/item/news_read.naver...
# 5   https://finance.naver.com/item/news_read.naver...
# 6   https://finance.naver.com/item/news_read.naver...
# 7   https://finance.naver.com/item/news_read.naver...
# 8   https://finance.naver.com/item/news_read.naver...
# 9   https://finance.naver.com/item/news_read.naver...
# 10  https://finance.naver.com/item/news_read.naver...
# 11  https://finance.naver.com/item/news_read.naver...
# 12  https://finance.naver.com/item/news_read.naver...
# 13  https://finance.naver.com/item/news_read.naver...
# 14  https://finance.naver.com/item/news_read.naver...
# 15  https://finance.naver.com/item/news_read.naver...
# 16  https://finance.naver.com/item/news_read.naver...
# 17  https://finance.naver.com/item/news_read.naver...
# 18  https://finance.naver.com/item/news_read.naver...
# 19  https://finance.naver.com/item/news_read.naver...
# 20  https://finance.naver.com/item/news_read.naver...
# 21  https://finance.naver.com/item/news_read.naver...
# 22  https://finance.naver.com/item/news_read.naver...
# 23  https://finance.naver.com/item/news_read.naver...
# 24  https://finance.naver.com/item/news_read.naver...
# 25  https://finance.naver.com/item/news_read.naver...
# 26  https://finance.naver.com/item/news_read.naver...
# 27  https://finance.naver.com/item/news_read.naver...
# 28  https://finance.naver.com/item/news_read.naver...
# 29  https://finance.naver.com/item/news_read.naver...
# 30  https://finance.naver.com/item/news_read.naver...
# 31  https://finance.naver.com/item/news_read.naver...
# 32  https://finance.naver.com/item/news_read.naver...
# 33  https://finance.naver.com/item/news_read.naver...
# 34  https://finance.naver.com/item/news_read.naver...
# 35  https://finance.naver.com/item/news_read.naver...
# 36  https://finance.naver.com/item/news_read.naver...
# 37  https://finance.naver.com/item/news_read.naver...

# %%
date_list = []
title_list = []
info_list = []
url_list = []

if company == '카카오':
    code = '035720' # kakao
else:
    code = '035420' # naver
page = 1

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.64 Safari/537.36 Edg/101.0.1210.32'}

url = f'https://finance.naver.com/item/news_news.naver?code={code}&page={page}&sm=title_entity_id.basic&clusterId='
res = requests.get(url, headers=headers)
bs = bs4.BeautifulSoup(res.text, 'html.parser')

while datetime.strftime(datetime.now().date() + timedelta(days=-day), '%Y-%m-%d') not in date_list:
    url = f'https://finance.naver.com/item/news_news.naver?code={code}&page={page}&sm=title_entity_id.basic&clusterId='
    res = requests.get(url, headers=headers)
    bs = bs4.BeautifulSoup(res.text, 'html.parser')

    date_list.extend([i.text.split()[0].replace('.', '-') for i in bs.find_all('td', {'class': 'date'})])
    title_list.extend([i.text.replace('\n', '').replace('[','').replace(']','') for i in bs.find_all('td', {'class': 'title'})])
    info_list.extend([i.text for i in bs.find_all('td', {'class': 'info'})])
    url_list.extend(
        ['https://finance.naver.com' + i.find('a')['href'] for i in bs.find_all('td', {'class': 'title'})])

    page += 1

data = pd.DataFrame([date_list, title_list, info_list, url_list], index=['날짜', '제목', '정보제공', '링크']).transpose()
data = data.drop_duplicates('제목')
data
# Out:
#             날짜                                         제목    정보제공  \
# 0   2022-06-08                네이버 '일할 맛나는' 신사옥 기술, 묶어서 판다  비즈니스워치
# 1   2022-06-08  (영상)네이버, 미래형공간 대중화 본격화..."공간 개념 확 바꿀 것...    이데일리
# 2   2022-06-08                  네이버 "5G·ARC 융합기술, 내년 상용화"    서울경제
# 3   2022-06-08            “5층까지 짓다가…” 네이버 1784, 비싼 건물된 사연    이데일리
# 4   2022-06-08            "로봇 아닌 '이것' 팔겠다" 네이버 밝힌 새 비즈니스는    매일경제
# 5   2022-06-08             네이버, ARC·5G특화망으로 '스마트빌딩 시장' 진출    매일경제
# 6   2022-06-08         네이버·카카오 등에 맞춤형 광고 집행…'크로스타겟' 확대 개편   머니투데이
# 7   2022-06-08   AI World 2022 성낙호 네이버 책임리더 "AI도 인간처럼 ...  파이낸셜뉴스
# 8   2022-06-08                         팀 네이버 ‘미래형 공간’ 대중화   헤럴드경제
# 9   2022-06-08             네이버, ‘1784 로봇’ 본뜬 스마트빌딩 대중화 목표    이데일리
# 10  2022-06-08  원하면 네이버 신사옥처럼 만들어드립니다…"로봇·클라우드 기술 2023...    서울경제
# 11  2022-06-08       네이버 노조 "계열사 초임은 '본사 절반'…임금 똑같이 인상해야"   머니투데이
# 12  2022-06-07            네이버플러스 멤버십 이용자 800만 돌파…상생도 꽃피운다  파이낸셜뉴스
# 13  2022-06-07           '한달 4900원' 네이버플러스 2년만에 800만명이 썼다   머니투데이
# 14  2022-06-07  "658만P 페이백받은 사용자도"…네이버 멤버십 1000만 돌파 '부...    서울경제
# 15  2022-06-07               네이버플러스 멤버십, 화끈한 적립에 파트너사 웃었다    이데일리
# 16  2022-06-07                   네이버, 세자릿수 신입 개발자 채용 진행한다  파이낸셜뉴스
# 17  2022-06-07      네이버, 나만의 성장 트랙 직접 설계하는 ‘신입 개발자’ 채용 진행    이데일리
# 18  2022-06-07                네이버, 세자릿수 규모 신입 및 인턴 개발자 채용   머니투데이
# 19  2022-06-07                      애플워치로 결제하는 '네이버페이' 출시    한국경제
# 20  2022-06-07                      네이버페이 현장결제…스마트워치로 손쉽게    매일경제
# 21  2022-06-07                네이버파이낸셜, 스마트워치용 '페이 워치앱' 출시    서울경제
# 22  2022-06-07             네이버파이낸셜, 스마트워치용 ‘네이버페이 워치앱’ 출시    조선비즈
# 23  2022-06-07          네이버파이낸셜 “이제 휴대폰 없이 워치로 네이버페이 쓰세요”  이코노미스트
# 24  2022-06-07                갤럭시·애플워치에서 네이버페이 결제된다…국내 최초   헤럴드경제
# 25  2022-06-07    크래프톤 임원 7명 중 6명이 40대…카카오·네이버도 비중 70% 넘어    한국경제
# 26  2022-06-07         (영상)삼성·네이버가 찍은 '이음5G' 확대일로...수혜주는?    이데일리
# 27  2022-06-07                특징주외국인 엇갈린 선택…네이버 카카오 나란히 뚝    이데일리
# 28  2022-06-07      교보악사자산운용, 네이버·카카오 투자하는 '플랫폼투게더' 펀드 출시    서울경제
# 29  2022-06-07           코스피·코스닥 하락 출발, 네이버·카카오 2%대↓ 개장시황  이코노미스트
# 30  2022-06-06  '인간지능과 AI의 만남'… KT·네이버·카카오엔터프라이즈 전략은 A...  파이낸셜뉴스
# 31  2022-06-06    AI World 2022 KT-네이버-카카오엔터프라이즈, AI 핵...  파이낸셜뉴스
# 32  2022-06-06                    매경이코노미, 네이버 구독자 100만 돌파    매일경제
# 33  2022-06-06                     코스피 주간 개인 순매도 1위 '네이버'    이데일리
# 34  2022-06-06            "성장주인가 가치주인가"…네이버·카카오 주가 부진한 이유    한국경제
# 35  2022-06-05                    성장주 저문다더니…네이버 카카오 바닥찍었나   아시아경제
# 36  2022-06-05                  존재감 커진 네이버 웨일…점유율 10%대 눈앞  매경이코노미
# 37  2022-06-03           네이버 노조 "계열사 5곳 임금교섭 결렬…중노위 조정신청"   머니투데이
#
#                                                    링크
# 0   https://finance.naver.com/item/news_read.naver...
# 1   https://finance.naver.com/item/news_read.naver...
# 2   https://finance.naver.com/item/news_read.naver...
# 3   https://finance.naver.com/item/news_read.naver...
# 4   https://finance.naver.com/item/news_read.naver...
# 5   https://finance.naver.com/item/news_read.naver...
# 6   https://finance.naver.com/item/news_read.naver...
# 7   https://finance.naver.com/item/news_read.naver...
# 8   https://finance.naver.com/item/news_read.naver...
# 9   https://finance.naver.com/item/news_read.naver...
# 10  https://finance.naver.com/item/news_read.naver...
# 11  https://finance.naver.com/item/news_read.naver...
# 12  https://finance.naver.com/item/news_read.naver...
# 13  https://finance.naver.com/item/news_read.naver...
# 14  https://finance.naver.com/item/news_read.naver...
# 15  https://finance.naver.com/item/news_read.naver...
# 16  https://finance.naver.com/item/news_read.naver...
# 17  https://finance.naver.com/item/news_read.naver...
# 18  https://finance.naver.com/item/news_read.naver...
# 19  https://finance.naver.com/item/news_read.naver...
# 20  https://finance.naver.com/item/news_read.naver...
# 21  https://finance.naver.com/item/news_read.naver...
# 22  https://finance.naver.com/item/news_read.naver...
# 23  https://finance.naver.com/item/news_read.naver...
# 24  https://finance.naver.com/item/news_read.naver...
# 25  https://finance.naver.com/item/news_read.naver...
# 26  https://finance.naver.com/item/news_read.naver...
# 27  https://finance.naver.com/item/news_read.naver...
# 28  https://finance.naver.com/item/news_read.naver...
# 29  https://finance.naver.com/item/news_read.naver...
# 30  https://finance.naver.com/item/news_read.naver...
# 31  https://finance.naver.com/item/news_read.naver...
# 32  https://finance.naver.com/item/news_read.naver...
# 33  https://finance.naver.com/item/news_read.naver...
# 34  https://finance.naver.com/item/news_read.naver...
# 35  https://finance.naver.com/item/news_read.naver...
# 36  https://finance.naver.com/item/news_read.naver...
# 37  https://finance.naver.com/item/news_read.naver...
