# %%
import pandas as pd

# %%
df = pd.read_csv('./src/네이버금융종목뉴스기사본문_카카오_전체_전처리후_관련기사제거.csv')

# %%
df
# Out:
#               날짜                                          제목    정보제공  \
# 0     2022-04-29             "미래 푸드테크, 삼성·SK·네이버·카카오도 진출할 것"   머니투데이
# 1     2022-04-29              ‘상생 행보’ 카카오…중기유통센터 손잡고 소상공인 지원  이코노미스트
# 2     2022-04-28              "카카오·네이버보다도 못하다고?"…삼성맨들 '부글부글'    한국경제
# 3     2022-04-28  2040년까지 탄소 순 배출량 '0' 만든다…카카오 '넷 제로' 원칙 ...  이코노미스트
# 4     2022-04-28              카카오 공동체, 'RE100' 가입 추진..ESG 강화  파이낸셜뉴스
# ...          ...                                         ...     ...
# 3675  2021-05-03                  카카오-카카오커머스, ‘톡스토어 판매자’ 키운다  파이낸셜뉴스
# 3676  2021-05-03             카카오·카카오커머스, '톡스토어' 판매자 양성 과정 진행    서울경제
# 3677  2021-05-01             KT와 카카오의 공유자전거 힘겨루기…T바이크에 타조 맞불    매일경제
# 3678  2021-04-30             네이버 오른다는데…공매도 타깃된 카카오 "나 떨고있니?"   머니투데이
# 3679  2021-04-30               카카오내비, ‘방문 정비’ 시작 “주행분석까지 한다”  파이낸셜뉴스
#
#                                                      링크  \
# 0     https://finance.naver.com/item/news_read.naver...
# ...

# %%
df = pd.read_csv('./src/네이버금융종목뉴스기사본문_카카오_전체_전처리후.csv')

# %%
df
# Out:
#               날짜                                          제목    정보제공  \
# 0     2022-04-29             "미래 푸드테크, 삼성·SK·네이버·카카오도 진출할 것"   머니투데이
# 1     2022-04-29              ‘상생 행보’ 카카오…중기유통센터 손잡고 소상공인 지원  이코노미스트
# 2     2022-04-29                  소상공인 파트너와 성장하는 ‘톡스토어’..카카오  파이낸셜뉴스
# 3     2022-04-28              "카카오·네이버보다도 못하다고?"…삼성맨들 '부글부글'    한국경제
# 4     2022-04-28  2040년까지 탄소 순 배출량 '0' 만든다…카카오 '넷 제로' 원칙 ...  이코노미스트
# ...          ...                                         ...     ...
# 5571  2021-05-03                  카카오-카카오커머스, ‘톡스토어 판매자’ 키운다  파이낸셜뉴스
# 5572  2021-05-03             카카오·카카오커머스, '톡스토어' 판매자 양성 과정 진행    서울경제
# 5573  2021-05-01             KT와 카카오의 공유자전거 힘겨루기…T바이크에 타조 맞불    매일경제
# 5574  2021-04-30             네이버 오른다는데…공매도 타깃된 카카오 "나 떨고있니?"   머니투데이
# 5575  2021-04-30               카카오내비, ‘방문 정비’ 시작 “주행분석까지 한다”  파이낸셜뉴스
#
#                                                      링크  \
# 0     https://finance.naver.com/item/news_read.naver...
# ...
