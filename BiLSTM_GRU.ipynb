# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
df = pd.read_csv('./src/naver_shop.csv')

# %%
df
# Out:
#                                                        리뷰  긍정  부정
# 0                                                 배공빠르고 굿   1   0
# 1                           택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고   0   1
# 2       아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...   1   0
# 3       선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...   0   1
# 4                       민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ   1   0
# ...                                                   ...  ..  ..
# 199995                                    장마라그런가!!! 달지않아요   0   1
# 199996  다이슨 케이스 구매했어요 다이슨 슈퍼소닉 드라이기 케이스 구매했어요가격 괜찮고 배송...   1   0
# 199997                    로드샾에서 사는것보다 세배 저렴하네요 ㅜㅜ 자주이용할께요   1   0
# 199998                                      넘이쁘고 쎄련되보이네요~   1   0
# 199999   아직 사용해보지도않았고 다른 제품을 써본적이없어서 잘 모르겠지만 ㅎㅎ 배송은 빨랐습니다   1   0
#
# [200000 rows x 3 columns]
