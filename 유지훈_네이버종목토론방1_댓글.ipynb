# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

# %%
code = '035720' # 카카오 종목코드
page = 15000 # 크롤 희망 페이지 (페이지당 20개 댓글)

date_list = [] # 날짜
comment_list = [] # 댓글
view_list = [] # 조회수
good_list = [] # 좋아요
bad_list = [] # 싫어요

for i in range(1,page+1):
    url = f'https://finance.naver.com/item/board.naver?code={code}&page={i}'
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36 Edg/100.0.1185.50'}
    res = requests.get(url, headers = headers)
    bs = BeautifulSoup(res.text, 'html.parser')
    
    for j in range(20):
        try:
            root = bs.find('div',{'class':'section inner_sub'}).find_all('tr',{'onmouseover':'mouseOver(this)'})[j].text.split('\n')
            
            date_list.append(root[1].split()[0].replace('.','-'))
            if len(root) == 14: # 답글
                comment_list.append('답글:'+root[4])
                view_list.append(root[10])
                good_list.append(root[11])
                bad_list.append(root[12])          
            elif len(root) == 13: # 기본
                comment_list.append(root[3])
                view_list.append(root[9])
                good_list.append(root[10])
                bad_list.append(root[11])
            else: # 에러
                comment_list.append('error')
                view_list.append(0)
                good_list.append(0)
                bad_list.append(0)   
                
        except:
            date_list.append('error')
            comment_list.append('error')
            view_list.append(0)
            good_list.append(0)
            bad_list.append(0)   
            
    
    if i % 500 == 0:
        print(f'{i}페이지 크롤링 완료')
# Out:
# 500페이지 크롤링 완료
# 1000페이지 크롤링 완료
# 1500페이지 크롤링 완료
# 2000페이지 크롤링 완료
# 2500페이지 크롤링 완료
# 3000페이지 크롤링 완료
# 3500페이지 크롤링 완료
# 4000페이지 크롤링 완료
# 4500페이지 크롤링 완료
# 5000페이지 크롤링 완료
# 5500페이지 크롤링 완료
# 6000페이지 크롤링 완료
# 6500페이지 크롤링 완료
# 7000페이지 크롤링 완료
# 7500페이지 크롤링 완료
# 8000페이지 크롤링 완료
# 8500페이지 크롤링 완료
# 9000페이지 크롤링 완료
# 9500페이지 크롤링 완료
# 10000페이지 크롤링 완료
# 10500페이지 크롤링 완료
# 11000페이지 크롤링 완료
# 11500페이지 크롤링 완료
# 12000페이지 크롤링 완료
# 12500페이지 크롤링 완료
# 13000페이지 크롤링 완료
# 13500페이지 크롤링 완료
# 14000페이지 크롤링 완료
# 14500페이지 크롤링 완료
# 15000페이지 크롤링 완료

# %%
df = pd.DataFrame()
df['날짜'] = date_list
df['댓글'] = comment_list
df['조회수'] = view_list
df['좋아요'] = good_list
df['싫어요'] = bad_list
df
# Out:
#                 날짜                         댓글  조회수 좋아요 싫어요
# 0       2022-05-03                  개미들 조련하는법   26   1   0
# 1       2022-05-03                        6만원   38   1   0
# 2       2022-05-03             카카오는 끝물입니다 사실상   72   2   2
# 3       2022-05-03                    안티 살발하다   34   2   0
# 4       2022-05-03            이런 호로개미지옥탕을 만드신   58   3   1
# ...            ...                        ...  ...  ..  ..
# 299995  2017-10-18  어차피 또 폭등할텐데 떨필요있나 기회주면...  795  15   3
# 299996  2017-10-18  오늘 물렸다고 생각하는 사람들은 도대체 ...  961   3   2
# 299997  2017-10-18                        내일도  618   5   1
# 299998  2017-10-18              아마존 per는 300?  745   4   1
# 299999  2017-10-18                  퍼가 180???  563   2   3
#
# [300000 rows x 5 columns]

# %%
df[df['댓글'] != 'error']
# Out:
#                 날짜                         댓글  조회수 좋아요 싫어요
# 0       2022-05-03                  개미들 조련하는법   26   1   0
# 1       2022-05-03                        6만원   38   1   0
# 2       2022-05-03             카카오는 끝물입니다 사실상   72   2   2
# 3       2022-05-03                    안티 살발하다   34   2   0
# 4       2022-05-03            이런 호로개미지옥탕을 만드신   58   3   1
# ...            ...                        ...  ...  ..  ..
# 299995  2017-10-18  어차피 또 폭등할텐데 떨필요있나 기회주면...  795  15   3
# 299996  2017-10-18  오늘 물렸다고 생각하는 사람들은 도대체 ...  961   3   2
# 299997  2017-10-18                        내일도  618   5   1
# 299998  2017-10-18              아마존 per는 300?  745   4   1
# 299999  2017-10-18                  퍼가 180???  563   2   3
#
# [299991 rows x 5 columns]

# %%
df.to_csv("./src/네이버종토방댓글_카카오_15000.csv", index=False)
